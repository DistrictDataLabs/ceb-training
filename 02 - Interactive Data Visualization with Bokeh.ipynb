# %% [markdown]
# # Interactive Data Visualization with Bokeh
#
# This notebook serves as a brief introduction to Bokeh with Python.

# %%
import numpy as np
import pandas as pd

# Bokeh Essentials 
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, ColumnDataSource

# Bokeh Helpers 
from bokeh.palettes import brewer
from bokeh.models import HoverTool

# %%
# Load Bokeh for visualization
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="82f01ada-15c0-488a-9862-0037ee0b62fe">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Topic Model Visualization
#
# In this section we'll take a look at visualizing a corpus by exploring clustering and dimensionality reduction techniques. Text analysis is certainly high dimensional visualization and this can be applied to other data sets as well.
#
# The first step is to load our documents from disk and vectorize them using Gensim. This content is a bit beyond the scope of the workshop for today, however I did want to provide code for reference, and I'm happy to go over it offline.

# %%
import nltk 
import string
import pickle
import gensim
import random 

from operator import itemgetter
from collections import defaultdict 
from nltk.corpus import wordnet as wn
from gensim.matutils import sparse2full
from nltk.corpus.reader.api import CorpusReader
from nltk.corpus.reader.api import CategorizedCorpusReader

CORPUS_PATH = "data/baleen_sample"
PKL_PATTERN = r'(?!\.)[a-z_\s]+/[a-f0-9]+\.pickle'
CAT_PATTERN = r'([a-z_\s]+)/.*'
# Out:
# /usr/local/lib/python3.5/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %%
class PickledCorpus(CategorizedCorpusReader, CorpusReader):
    
    def __init__(self, root, fileids=PKL_PATTERN, cat_pattern=CAT_PATTERN):
        CategorizedCorpusReader.__init__(self, {"cat_pattern": cat_pattern})
        CorpusReader.__init__(self, root, fileids)
        
        self.punct = set(string.punctuation) | {'“', '—', '’', '”', '…'}
        self.stopwords = set(nltk.corpus.stopwords.words('english'))
        self.wordnet = nltk.WordNetLemmatizer() 
    
    def _resolve(self, fileids, categories):
        if fileids is not None and categories is not None:
            raise ValueError("Specify fileids or categories, not both")

        if categories is not None:
            return self.fileids(categories=categories)
        return fileids
    
    def lemmatize(self, token, tag):
        token = token.lower()
        
        if token not in self.stopwords:
            if not all(c in self.punct for c in token):
                tag =  {
                    'N': wn.NOUN,
                    'V': wn.VERB,
                    'R': wn.ADV,
                    'J': wn.ADJ
                }.get(tag[0], wn.NOUN)
                return self.wordnet.lemmatize(token, tag)
    
    def tokenize(self, doc):
        # Expects a preprocessed document, removes stopwords and punctuation
        # makes all tokens lowercase and lemmatizes them. 
        return list(filter(None, [
            self.lemmatize(token, tag)
            for paragraph in doc 
            for sentence in paragraph 
            for token, tag in sentence 
        ]))
    
    def docs(self, fileids=None, categories=None):
        # Resolve the fileids and the categories
        fileids = self._resolve(fileids, categories)

        # Create a generator, loading one document into memory at a time.
        for path, enc, fileid in self.abspaths(fileids, True, True):
            with open(path, 'rb') as f:
                yield self.tokenize(pickle.load(f))

# %% [markdown]
# The `PickledCorpus` is a Python class that reads a continuous stream of pickle files from disk. The files themselves are preprocessed documents from RSS feeds in various topics (and is actually just a small sample of the documents that are in the larger corpus). If you're interestd in the ingestion and curation of this corpus, see [baleen.districtdatalabs.com](http://baleen.districtdatalabs.com).
#
# Just to get a feel for this data set, I'll load the corpus and print out the number of documents per category:

# %%
# Create the Corpus Reader
corpus = PickledCorpus(CORPUS_PATH)

# %%
# Count the total number of documents
total_docs = 0

# Count the number of documents per category. 
for category in corpus.categories():
    num_docs = sum(1 for doc in corpus.fileids(categories=[category]))
    total_docs += num_docs 
    
    print("{}: {:,} documents".format(category, num_docs))
    
print("\n{:,} documents in the corpus".format(total_docs))
# Out:
# books: 71 documents
# business: 389 documents
# cinema: 100 documents
# cooking: 30 documents
# data_science: 41 documents
# design: 55 documents
# do_it_yourself: 122 documents
# gaming: 128 documents
# news: 1,159 documents
# politics: 149 documents
# sports: 118 documents
# tech: 176 documents
#
# 2,538 documents in the corpus

# %% [markdown]
# Our corpus reader object handles text preprocessing with NLTK (the natural language toolkit), namely by converting each document as follows:
#
# - tokenizing the document
# - making all tokens lower case
# - removes stopwords and punctuation
# - converts words to their lemma
#
# Here is an example document:

# %%
fid = random.choice(corpus.fileids())
doc = next(corpus.docs(fileids=[fid]))
print(" ".join(doc))
# Out:
# washington storm cloud gather around campaign donald trump drop everything thursday andhad unscheduled meeting republican party leader gop front runner campaign request meeting discuss delegate allocation party rule less concrete pledge support eventual gop nominee nothing resolve trump trail wisconsin loss tuesday would increase chance republican convention july would begin without clear cut nominee republican leader remain anxious trump standard bearer comment wednesday msnbc would happen abortion outlaw answer form punishment trump say ask mean punish woman seek abortion say yeah form trump later reverse say punishment would reserve doctor john kasich say thursday would turn woman family decide could back trump nominee point nature election go matter wife daughter think ohio governor say trump past say campaign trail phenomenal issue important woman great woman health issue claim great woman cherish woman great respect woman cherish woman top abortion comment trump disparage female journalist candidate defend campaign manager charge battery grab female reporter general election match ups trump trail hillary clinton 20 point woman 23 point bernie sander trump also battle history republican nominee majority woman voter since 1988 2012 mitt romney lose woman 11 point recent cbs news poll show trump 57 percent unfavorability rating high presidential front runner date back 1984 sixty three percent woman view trump unfavorably 22 point high romney four year ago © 2016 cbs interactive inc right reserved

# %% [markdown]
# The next step is to convert these documents into vectors so that we can apply machine learning. We'll use a bag-of-words (bow) model with TF-IDF, implemented by the Gensim library.

# %%
# Create the lexicon from the corpus 
lexicon = gensim.corpora.Dictionary(corpus.docs())

# Create the document vectors 
docvecs = [lexicon.doc2bow(doc) for doc in corpus.docs()]

# Train the TF-IDF model and convert vectors to TF-IDF
tfidf = gensim.models.TfidfModel(docvecs, id2word=lexicon, normalize=True)
tfidfvecs = [tfidf[doc] for doc in docvecs]

# Save the lexicon and TF-IDF model to disk.
lexicon.save('data/topics/lexicon.dat')
tfidf.save('data/topics/tfidf_model.pkl')

# %% [markdown]
# Documents are now described by the words that are most important to that document relative to the rest of the corpus. The document above has been transformed into the following vector with associated weights:

# %%
# Covert random document from above into TF-IDF vector 
dv = tfidf[lexicon.doc2bow(doc)]

# Print the document terms and their weights. 
print(" ".join([
    "{} ({:0.2f})".format(lexicon[tid], score)
    for tid, score in sorted(dv, key=itemgetter(1), reverse=True)
]))
# Out:
# trump (0.41) woman (0.38) abortion (0.22) cherish (0.20) nominee (0.19) trail (0.17) punishment (0.14) republican (0.13) romney (0.13) campaign (0.13) andhad (0.12) unscheduled (0.12) point (0.12) cbs (0.11) female (0.11) unfavorably (0.11) unfavorability (0.11) phenomenal (0.10) runner (0.10) bearer (0.10) gop (0.09) disparage (0.09) outlaw (0.09) sixty (0.09) allocation (0.08) meeting (0.08) anxious (0.08) eventual (0.08) election (0.08) great (0.08) 1984 (0.08) 1988 (0.07) form (0.07) msnbc (0.07) front (0.07) would (0.07) leader (0.07) concrete (0.07) punish (0.07) percent (0.07) ups (0.07) reverse (0.07) wisconsin (0.07) mitt (0.07) battery (0.07) thursday (0.07) storm (0.06) cloud (0.06) yeah (0.06) 57 (0.06) party (0.06) resolve (0.06) rating (0.06) reserved (0.06) comment (0.06) grab (0.06) © (0.06) reserve (0.06) pledge (0.06) doctor (0.06) issue (0.06) respect (0.05) nature (0.05) interactive (0.05) kasich (0.05) gather (0.05) ohio (0.05) journalist (0.05) governor (0.05) convention (0.05) delegate (0.05) bernie (0.05) daughter (0.05) july (0.05) sander (0.05) defend (0.05) match (0.05) majority (0.05) inc (0.05) poll (0.05) standard (0.05) discuss (0.05) 23 (0.05) voter (0.05) wife (0.05) request (0.05) manager (0.05) 22 (0.04) high (0.04) loss (0.04) battle (0.04) 2012 (0.04) say (0.04) health (0.04) hillary (0.04) chance (0.04) reporter (0.04) date (0.04) clinton (0.04) answer (0.04) drop (0.04) nothing (0.04) view (0.04) matter (0.04) back (0.04) seek (0.04) wednesday (0.04) rule (0.04) everything (0.04) charge (0.04) 11 (0.04) history (0.04) increase (0.04) candidate (0.04) cut (0.04) presidential (0.04) decide (0.03) general (0.03) donald (0.03) claim (0.03) washington (0.03) john (0.03) important (0.03) clear (0.03) 20 (0.03) lose (0.03) tuesday (0.03) ago (0.03) recent (0.03) less (0.03) remain (0.03) past (0.03) later (0.03) happen (0.03) family (0.03) without (0.03) top (0.03) support (0.03) begin (0.03) four (0.03) mean (0.03) turn (0.03) ask (0.03) news (0.02) around (0.02) 2016 (0.02) three (0.02) since (0.02) right (0.02) think (0.02) show (0.02) could (0.02) go (0.01) also (0.01) year (0.01)

# %% [markdown]
# ### Topic Visualization with LDA
#
# We have a lot of documents in our corpus, so let's see if we can cluster them into related topics using the Latent Dirichlet Model that comes with Gensim. This model is widely used for "topic modeling" -- that is clustering on documents.

# %%
# Select the number of topics to train the model on.
NUM_TOPICS = 10 

# Create the LDA model from the docvecs corpus and save to disk.
model = gensim.models.LdaModel(docvecs, id2word=lexicon, alpha='auto', num_topics=NUM_TOPICS)
model.save('data/topics/lda_model.pkl')

# %% [markdown]
# Each topic is represented as a vector - where each word is a dimension and the probability of that word beloning to the topic is the value. We can use the model to query the topics for a document, our random document from above is assigned the following topics with associated probabilities:

# %%
model[lexicon.doc2bow(doc)]
# Out:
# [(5, 0.36703245668474188), (7, 0.6278914783207119)]

# %% [markdown]
# We can assign the most probable topic to each document in our corpus by selecting the topic with the maximal probability:

# %%
topics = [
    max(model[doc], key=itemgetter(1))[0]
    for doc in docvecs
]

# %% [markdown]
# Topics themselves can be described by their highest probability words:

# %%
for tid, topic in model.print_topics():
    print("Topic {}:\n{}\n".format(tid, topic))
# Out:
# Topic 0:
# 0.007*"say" + 0.006*"june" + 0.005*"one" + 0.005*"may" + 0.005*"new" + 0.004*"1" + 0.004*"also" + 0.004*"year" + 0.004*"time" + 0.003*"first"
#
# Topic 1:
# 0.015*"say" + 0.006*"state" + 0.004*"also" + 0.004*"u" + 0.004*"people" + 0.004*"one" + 0.004*"new" + 0.003*"would" + 0.003*"use" + 0.003*"year"
#
# Topic 2:
# 0.012*"say" + 0.005*"one" + 0.005*"year" + 0.005*"make" + 0.004*"also" + 0.004*"time" + 0.004*"u" + 0.003*"would" + 0.003*"use" + 0.003*"like"
#
# Topic 3:
# 0.009*"say" + 0.006*"game" + 0.005*"sander" + 0.005*"go" + 0.004*"like" + 0.004*"clinton" + 0.004*"state" + 0.004*"time" + 0.004*"make" + 0.004*"one"
#
# Topic 4:
# 0.008*"say" + 0.005*"year" + 0.005*"make" + 0.005*"game" + 0.004*"one" + 0.004*"also" + 0.004*"get" + 0.004*"first" + 0.004*"new" + 0.004*"people"
#
# Topic 5:
# 0.008*"say" + 0.006*"like" + 0.006*"trump" + 0.005*"year" + 0.005*"make" + 0.005*"get" + 0.005*"new" + 0.005*"one" + 0.004*"would" + 0.004*"take"
#
# Topic 6:
# 0.013*"say" + 0.006*"year" + 0.004*"state" + 0.004*"make" + 0.004*"u" + 0.004*"would" + 0.004*"go" + 0.004*"time" + 0.004*"new" + 0.004*"one"
#
# Topic 7:
# 0.012*"say" + 0.009*"trump" + 0.006*"go" + 0.006*"year" + 0.006*"one" + 0.005*"republican" + 0.004*"make" + 0.004*"get" + 0.004*"mr" + 0.004*"would"
#
# Topic 8:
# 0.008*"say" + 0.004*"one" + 0.004*"trump" + 0.004*"year" + 0.004*"two" + 0.003*"state" + 0.003*"take" + 0.003*"get" + 0.003*"time" + 0.003*"people"
#
# Topic 9:
# 0.005*"say" + 0.005*"one" + 0.004*"nba" + 0.004*"get" + 0.004*"game" + 0.004*"make" + 0.004*"time" + 0.003*"vr" + 0.003*"u" + 0.003*"data"

# %% [markdown]
# We can plot each topic by using decomposition methods (TruncatedSVD in this case) to reduce the probability vector for each topic into 2 dimensions, then size the radius of each topic according to how much probability documents it contains donates to it. Also try with PCA, explored below!

# %%
# Create a sum dictionary that adds up the total probability 
# of each document in the corpus to each topic. 
tsize = defaultdict(float)
for doc in docvecs:
    for tid, prob in model[doc]:
        tsize[tid] += prob

# %%
# Create a numpy array of topic vectors where each vector 
# is the topic probability of all terms in the lexicon. 
tvecs = np.array([
    sparse2full(model.get_topic_terms(tid, len(lexicon)), len(lexicon)) 
    for tid in range(NUM_TOPICS)
])

# %%
# Import the model family 
from sklearn.decomposition import TruncatedSVD 

# Instantiate the model form, fit and transform 
topic_svd = TruncatedSVD(n_components=2)
svd_tvecs = topic_svd.fit_transform(tvecs)

# %%
# Create the Bokeh columnar data source with our various elements. 
# Note the resize/normalization of the topics so the radius of our
# topic circles fits int he graph a bit better. 
tsource = ColumnDataSource(
        data=dict(
            x=svd_tvecs[:, 0],
            y=svd_tvecs[:, 1],
            w=[model.print_topic(tid, 10) for tid in range(10)],
            c=brewer['Spectral'][10],
            r=[tsize[idx]/700000.0 for idx in range(10)],
        )
    )

# Create the hover tool so that we can visualize the topics. 
hover = HoverTool(
        tooltips=[
            ("Words", "@w"),
        ]
    )


# Create the figure to draw the graph on. 
plt = figure(
    title="Topic Model Decomposition", 
    width=960, height=540, 
    tools="pan,box_zoom,reset,resize,save"
)

# Add the hover tool 
plt.add_tools(hover)

# Plot the SVD topic dimensions as a scatter plot 
plt.scatter(
    'x', 'y', source=tsource, size=9,
    radius='r', line_color='c', fill_color='c',
    marker='circle', fill_alpha=0.85,
)

# Show the plot to render the JavaScript 
show(plt)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="df4bd2cb-8a86-429d-9a1e-7d97d3605f05"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#df4bd2cb-8a86-429d-9a1e-7d97d3605f05").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("df4bd2cb-8a86-429d-9a1e-7d97d3605f05");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'df4bd2cb-8a86-429d-9a1e-7d97d3605f05' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e655f76c-b022-4757-86f8-6c438bafb4f8":{"roots":{"references":[{"attributes":{},"id":"5150d3d9-8335-4174-9daf-e62f8ab7a84f","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"field":"r","units":"data"},"size":{"units":"screen","value":9},"x":{"field":"x"},"y":{"field":"y"}},"id":"b4cc090d-396a-4413-b325-d67e43af4974","type":"Circle"},{"attributes":{"callback":null,"plot":{"id":"e2c613ac-344f-46ac-ba4e-4f29be7375a3","subtype":"Figure","type":"Plot"},"tooltips":[["Words","@w"]]},"id":"5b51d42d-b129-4a94-8d61-2d2f895f2f65","type":"HoverTool"},{"attributes":{},"id":"617ccf6a-30f4-4c87-9055-59ea01f02532","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Topic Model Decomposition"},"id":"90da773d-6106-44dd-8088-cb9fa3949f61","type":"Title"},{"attributes":{"callback":null,"column_names":["r","c","w","y","x"],"data":{"c":["#5e4fa2","#3288bd","#66c2a5","#abdda4","#e6f598","#fee08b","#fdae61","#f46d43","#d53e4f","#9e0142"],"r":[0.000199749792040389,0.00039486617492660864,0.000663336454578365,0.00023090697527595102,0.00037979429266413975,0.0006495520378376324,0.0003856073990430494,0.00048217999781566625,0.00010118014560290897,0.0001096959645718766],"w":["0.007*\"say\" + 0.006*\"june\" + 0.005*\"one\" + 0.005*\"may\" + 0.005*\"new\" + 0.004*\"1\" + 0.004*\"also\" + 0.004*\"year\" + 0.004*\"time\" + 0.003*\"first\"","0.015*\"say\" + 0.006*\"state\" + 0.004*\"also\" + 0.004*\"u\" + 0.004*\"people\" + 0.004*\"one\" + 0.004*\"new\" + 0.003*\"would\" + 0.003*\"use\" + 0.003*\"year\"","0.012*\"say\" + 0.005*\"one\" + 0.005*\"year\" + 0.005*\"make\" + 0.004*\"also\" + 0.004*\"time\" + 0.004*\"u\" + 0.003*\"would\" + 0.003*\"use\" + 0.003*\"like\"","0.009*\"say\" + 0.006*\"game\" + 0.005*\"sander\" + 0.005*\"go\" + 0.004*\"like\" + 0.004*\"clinton\" + 0.004*\"state\" + 0.004*\"time\" + 0.004*\"make\" + 0.004*\"one\"","0.008*\"say\" + 0.005*\"year\" + 0.005*\"make\" + 0.005*\"game\" + 0.004*\"one\" + 0.004*\"also\" + 0.004*\"get\" + 0.004*\"first\" + 0.004*\"new\" + 0.004*\"people\"","0.008*\"say\" + 0.006*\"like\" + 0.006*\"trump\" + 0.005*\"year\" + 0.005*\"make\" + 0.005*\"get\" + 0.005*\"new\" + 0.005*\"one\" + 0.004*\"would\" + 0.004*\"take\"","0.013*\"say\" + 0.006*\"year\" + 0.004*\"state\" + 0.004*\"make\" + 0.004*\"u\" + 0.004*\"would\" + 0.004*\"go\" + 0.004*\"time\" + 0.004*\"new\" + 0.004*\"one\"","0.012*\"say\" + 0.009*\"trump\" + 0.006*\"go\" + 0.006*\"year\" + 0.006*\"one\" + 0.005*\"republican\" + 0.004*\"make\" + 0.004*\"get\" + 0.004*\"mr\" + 0.004*\"would\"","0.008*\"say\" + 0.004*\"one\" + 0.004*\"trump\" + 0.004*\"year\" + 0.004*\"two\" + 0.003*\"state\" + 0.003*\"take\" + 0.003*\"get\" + 0.003*\"time\" + 0.003*\"people\"","0.005*\"say\" + 0.005*\"one\" + 0.004*\"nba\" + 0.004*\"get\" + 0.004*\"game\" + 0.004*\"make\" + 0.004*\"time\" + 0.003*\"vr\" + 0.003*\"u\" + 0.003*\"data\""],"x":[0.022617916901218203,0.02662271313678881,0.02669707113864363,0.025459214012745767,0.02624391152680743,0.02631409291743078,0.02688015001326975,0.029613279811485368,0.022883206079624744,0.020212541622947593],"y":[-0.0006908988629227028,0.011319761525956944,0.0034150112903017014,-0.005824940062356905,-0.0027511621682018684,-0.003881324406156117,0.006233604756223677,-0.005877330741854512,-0.0006019890692671061,-0.001682689825900336]}},"id":"5b3a26a6-b9a5-412c-a486-f920c420fafa","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"e2c613ac-344f-46ac-ba4e-4f29be7375a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"d32edfb4-7de6-43a6-befd-14228d567d61","type":"BasicTicker"}},"id":"efc53b99-9daf-4cc6-ade7-abecf81b8f62","type":"Grid"},{"attributes":{"formatter":{"id":"617ccf6a-30f4-4c87-9055-59ea01f02532","type":"BasicTickFormatter"},"plot":{"id":"e2c613ac-344f-46ac-ba4e-4f29be7375a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"d32edfb4-7de6-43a6-befd-14228d567d61","type ...

# %% [markdown]
# ### Corpus Visualization with PCA
#
# The bag of words model means that every token (string representation of a word) is a dimension and a document is represented by a vector that maps the relative weight of that dimension to the document by the TF-IDF metric. In order to visualize documents in this high dimensional space, we must use decomposition methods to reduce the dimensionality to something we can plot.
#
# One good first attempt is toi use principle component analysis (PCA) to reduce the data set dimensions (the number of vocabulary words in the corpus) to 2 dimensions in order to map the corpus as a scatter plot.
#
# We'll use the Scikit-Learn PCA transformer to do this work:

# %%
# In order to use Scikit-Learn we need to transform Gensim vectors into a numpy Matrix. 
docarr = np.array([sparse2full(vec, len(lexicon)) for vec in tfidfvecs])

# %%
# Import the model family 
from sklearn.decomposition import PCA 

# Instantiate the model form, fit and transform 
tfidf_pca = PCA(n_components=2)
pca_dvecs = topic_svd.fit_transform(docarr)

# %% [markdown]
# We can now use Bokeh to create an interactive plot that will allow us to explore documents according to their position in decomposed TF-IDF space, coloring by their topic.

# %%
# Create a map using the ColorBrewer 'Paired' Palette to assign 
# Topic IDs to specific colors. 
cmap = {
    i: brewer['Paired'][10][i]
    for i in range(10)
}

# Create a tokens listing for our hover tool. 
tokens = [
    " ".join([
        lexicon[tid] for tid, _ in sorted(doc, key=itemgetter(1), reverse=True)
    ][:10])
    for doc in tfidfvecs
]

# Create a Bokeh tabular data source to describe the data we've created. 
source = ColumnDataSource(
        data=dict(
            x=pca_dvecs[:, 0],
            y=pca_dvecs[:, 1],
            w=tokens,
            t=topics,
            c=[cmap[t] for t in topics],
        )
    )

# Create an interactive hover tool so that we can see the document. 
hover = HoverTool(
        tooltips=[
            ("Words", "@w"),
            ("Topic", "@t"),
        ]
    )

# Create the figure to draw the graph on. 
plt = figure(
    title="PCA Decomposition of BoW Space", 
    width=960, height=540, 
    tools="pan,box_zoom,reset,resize,save"
)

# Add the hover tool to the figure 
plt.add_tools(hover)

# Create the scatter plot with the PCA dimensions as the points. 
plt.scatter(
    'x', 'y', source=source, size=9,
    marker='circle_x', line_color='c', 
    fill_color='c', fill_alpha=0.5,
)

# Show the plot to render the JavaScript 
show(plt)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="125cc5b8-da5a-42d5-8b45-ed4b66c9d0fe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#125cc5b8-da5a-42d5-8b45-ed4b66c9d0fe").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("125cc5b8-da5a-42d5-8b45-ed4b66c9d0fe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '125cc5b8-da5a-42d5-8b45-ed4b66c9d0fe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a311446f-411f-4c34-935a-95f8ff16625e":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":9},"x":{"field":"x"},"y":{"field":"y"}},"id":"417b9e2e-b7e4-4b41-b41c-c6760600f09d","type":"CircleX"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"28f1a22e-dbff-4289-98c2-a423efa79837","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"28f1a22e-dbff-4289-98c2-a423efa79837","type":"BoxAnnotation"},"plot":{"id":"a0862ab4-1f86-4574-bb29-dd6b30f61c44","subtype":"Figure","type":"Plot"}},"id":"b24674d0-ccd7-49a0-8eda-c4c19727360d","type":"BoxZoomTool"},{"attributes":{},"id":"07618672-b220-44ca-8f90-34528e3e413b","type":"BasicTicker"},{"attributes":{"plot":{"id":"a0862ab4-1f86-4574-bb29-dd6b30f61c44","subtype":"Figure","type":"Plot"}},"id":"7d9b1f4d-fdc9-4181-aa25-a20fbdfa7739","type":"ResizeTool"},{"attributes":{"below":[{"id":"b046c8f1-e8d8-49cf-9568-c68569687aab","type":"LinearAxis"}],"left":[{"id":"6870fdb3-c0e6-434b-bae3-2df7353525db","type":"LinearAxis"}],"plot_height":540,"plot_width":960,"renderers":[{"id":"b046c8f1-e8d8-49cf-9568-c68569687aab","type":"LinearAxis"},{"id":"791804d4-e6ad-4720-b700-9f6f5dff6276","type":"Grid"},{"id":"6870fdb3-c0e6-434b-bae3-2df7353525db","type":"LinearAxis"},{"id":"15a51ec4-7686-4c10-8b2b-fa54a0cc97f9","type":"Grid"},{"id":"28f1a22e-dbff-4289-98c2-a423efa79837","type":"BoxAnnotation"},{"id":"cf95c629-4756-456e-a34f-e538db65d064","type":"GlyphRenderer"}],"title":{"id":"cc8363bb-0f29-4320-8d51-552562d9a7e1","type":"Title"},"tool_events":{"id":"4e5a42da-9017-41e5-a456-4bc23dc4c26e","type":"ToolEvents"},"toolbar":{"id":"27f9815e-8914-49a1-b8c6-d3e04fd30d9d","type":"Toolbar"},"x_range":{"id":"ca15386d-3610-4776-a369-762ac24932a8","type":"DataRange1d"},"y_range":{"id":"13df5de5-e7f2-4bbf-abad-5c8829546e7e","type":"DataRange1d"}},"id":"a0862ab4-1f86-4574-bb29-dd6b30f61c44","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"43b989bc-31c6-4c5a-9026-4c18418057bb","type":"BasicTickFormatter"},"plot":{"id":"a0862ab4-1f86-4574-bb29-dd6b30f61c44","subtype":"Figure","type":"Plot"},"ticker":{"id":"07618672-b220-44ca-8f90-34528e3e413b","type":"BasicTicker"}},"id":"6870fdb3-c0e6-434b-bae3-2df7353525db","type":"LinearAxis"},{"attributes":{"plot":{"id":"a0862ab4-1f86-4574-bb29-dd6b30f61c44","subtype":"Figure","type":"Plot"}},"id":"5f8d252d-79e3-4e3e-879f-9c4f8158298e","type":"PanTool"},{"attributes":{},"id":"f48ca469-58b1-487d-bd4b-85e4f93c61cd","type":"BasicTicker"},{"attributes":{"plot":{"id":"a0862ab4-1f86-4574-bb29-dd6b30f61c44","subtype":"Figure","type":"Plot"}},"id":"59d7c352-f300-4ec1-92cd-2ea0c217b0bb","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["c","w","y","t","x"],"data":{"c":["#b2df8a","#e31a1c","#b2df8a","#33a02c","#fb9a99","#b2df8a","#e31a1c","#fb9a99","#e31a1c","#6a3d9a","#a6cee3","#e31a1c","#e31a1c","#a6cee3","#e31a1c","#e31a1c","#a6cee3","#e31a1c","#e31a1c","#e31a1c","#b2df8a","#b2df8a","#e31a1c","#a6cee3","#a6cee3","#e31a1c","#e31a1c","#b2df8a","#e31a1c","#b2df8a","#e31a1c","#e31a1c","#1f78b4","#b2df8a","#a6cee3","#b2df8a","#b2df8a","#e31a1c","#6a3d9a","#b2df8a","#b2df8a","#b2df8a","#b2df8a","#e31a1c","#a6cee3","#e31a1c","#a6cee3","#e31a1c","#b2df8a","#fdbf6f","#b2df8a","#e31a1c","#cab2d6","#e31a1c","#b2df8a","#e31a1c","#b2df8a","#e31a1c","#fb9a99","#e31a1c","#b2df8a","#b2df8a","#a6cee3","#fb9a99","#e31a1c","#a6cee3","#1f78b4","#e31a1c","#e31a1c","#b2df8a","#e31a1c","#fb9a99","#fb9a99","#fb9a99","#1f78b4","#ff7f00","#ff7f00","#6a3d9a","#b2df8a","#e31a1c","#fdbf6f","#e31a1c","#1f78b4","#1f78b4","#fb9a99","#e31a1c","#e31a1c","# ...
